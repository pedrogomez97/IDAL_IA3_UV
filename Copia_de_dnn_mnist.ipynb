# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrogomez97/IDAL_IA3_UV/blob/main/Copia_de_dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (728)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model = tf.keras.models.Sequential()
model.add(Dense(units=256, activation = 'relu',input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(64, activation= 'relu'))
model.add(Dense(32, activation= 'relu'))
model.add(Dense(10, activation= 'softmax'))
#    .

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5074 - accuracy: 0.8424 - val_loss: 0.2119 - val_accuracy: 0.9364
# Epoch 2/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1563 - accuracy: 0.9545 - val_loss: 0.1400 - val_accuracy: 0.9593
# Epoch 3/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1090 - accuracy: 0.9676 - val_loss: 0.1010 - val_accuracy: 0.9694
# Epoch 4/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0806 - accuracy: 0.9756 - val_loss: 0.1021 - val_accuracy: 0.9679
# Epoch 5/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0642 - accuracy: 0.9807 - val_loss: 0.0873 - val_accuracy: 0.9734
# Epoch 6/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0506 - accuracy: 0.9845 - val_loss: 0.0796 - val_accuracy: 0.9760
# Epoch 7/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0396 - accuracy: 0.9878 - val_loss: 0.0793 - val_accuracy: 0.9765
# Epoch 8/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.0785 - val_accuracy: 0.9769
# Epoch 9/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.0748 - val_accuracy: 0.9795
# Epoch 10/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0721 - val_accuracy: 0.9797
# Epoch 11/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.0773 - val_accuracy: 0.9796
# Epoch 12/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0749 - val_accuracy: 0.9803
# Epoch 13/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.0805 - val_accuracy: 0.9783
# Epoch 14/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0823 - val_accuracy: 0.9787
# Epoch 15/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.1069 - val_accuracy: 0.9737
# Epoch 16/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0845 - val_accuracy: 0.9782
# Epoch 17/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0806 - val_accuracy: 0.9804
# Epoch 18/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.1093 - val_accuracy: 0.9735
# Epoch 19/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0950 - val_accuracy: 0.9785
# Epoch 20/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.1093 - val_accuracy: 0.9749
# Epoch 21/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0998 - val_accuracy: 0.9781
# Epoch 22/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0880 - val_accuracy: 0.9806
# Epoch 23/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0987 - val_accuracy: 0.9788
# Epoch 24/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1064 - val_accuracy: 0.9787
# Epoch 25/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0876 - val_accuracy: 0.9827
# Epoch 26/35
# 118/118 [==============================] - 2s 16ms/step - loss: 9.7159e-04 - accuracy: 0.9998 - val_loss: 0.0909 - val_accuracy: 0.9817
# Epoch 27/35
# 118/118 [==============================] - 2s 16ms/step - loss: 8.4676e-04 - accuracy: 0.9999 - val_loss: 0.0874 - val_accuracy: 0.9828
# Epoch 28/35
# 118/118 [==============================] - 2s 16ms/step - loss: 2.9327e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9825
# Epoch 29/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.8161e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9835
# Epoch 30/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.1159e-04 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9836
# Epoch 31/35
# 118/118 [==============================] - 2s 16ms/step - loss: 9.4219e-05 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9835
# Epoch 32/35
# 118/118 [==============================] - 2s 16ms/step - loss: 8.2310e-05 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9834
# Epoch 33/35
# 118/118 [==============================] - 2s 16ms/step - loss: 7.3169e-05 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9835
# Epoch 34/35
# 118/118 [==============================] - 2s 16ms/step - loss: 6.6483e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9837
# Epoch 35/35
# 118/118 [==============================] - 2s 16ms/step - loss: 6.0298e-05 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9833

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
reg=0.1
model_with_l2 = tf.keras.models.Sequential()
model_with_l2.add(Dense(units=256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 2s 18ms/step - loss: 6.2186 - accuracy: 0.2830 - val_loss: 2.0437 - val_accuracy: 0.2774
# Epoch 2/35
# 118/118 [==============================] - 2s 16ms/step - loss: 2.0005 - accuracy: 0.3358 - val_loss: 1.9649 - val_accuracy: 0.3602
# Epoch 3/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.9492 - accuracy: 0.3690 - val_loss: 1.9799 - val_accuracy: 0.3515
# Epoch 4/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.9164 - accuracy: 0.3859 - val_loss: 1.9381 - val_accuracy: 0.3638
# Epoch 5/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8935 - accuracy: 0.3995 - val_loss: 1.9066 - val_accuracy: 0.3859
# Epoch 6/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8789 - accuracy: 0.4051 - val_loss: 1.8719 - val_accuracy: 0.4219
# Epoch 7/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.8605 - accuracy: 0.4200 - val_loss: 1.8542 - val_accuracy: 0.4374
# Epoch 8/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8420 - accuracy: 0.4368 - val_loss: 1.8505 - val_accuracy: 0.4279
# Epoch 9/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8309 - accuracy: 0.4450 - val_loss: 1.8361 - val_accuracy: 0.4416
# Epoch 10/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8202 - accuracy: 0.4523 - val_loss: 1.8305 - val_accuracy: 0.4532
# Epoch 11/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8157 - accuracy: 0.4549 - val_loss: 1.8190 - val_accuracy: 0.4598
# Epoch 12/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.8052 - accuracy: 0.4623 - val_loss: 1.8192 - val_accuracy: 0.4521
# Epoch 13/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7999 - accuracy: 0.4640 - val_loss: 1.8183 - val_accuracy: 0.4665
# Epoch 14/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7873 - accuracy: 0.4795 - val_loss: 1.7875 - val_accuracy: 0.5021
# Epoch 15/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7766 - accuracy: 0.4944 - val_loss: 1.7825 - val_accuracy: 0.4914
# Epoch 16/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7695 - accuracy: 0.4974 - val_loss: 1.7742 - val_accuracy: 0.5103
# Epoch 17/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7619 - accuracy: 0.5034 - val_loss: 1.7671 - val_accuracy: 0.5088
# Epoch 18/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7569 - accuracy: 0.5048 - val_loss: 1.7647 - val_accuracy: 0.5028
# Epoch 19/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7502 - accuracy: 0.5100 - val_loss: 1.7574 - val_accuracy: 0.5065
# Epoch 20/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7447 - accuracy: 0.5122 - val_loss: 1.7765 - val_accuracy: 0.4948
# Epoch 21/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7405 - accuracy: 0.5159 - val_loss: 1.7657 - val_accuracy: 0.4914
# Epoch 22/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7355 - accuracy: 0.5155 - val_loss: 1.7527 - val_accuracy: 0.5084
# Epoch 23/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7310 - accuracy: 0.5183 - val_loss: 1.7367 - val_accuracy: 0.5173
# Epoch 24/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7253 - accuracy: 0.5214 - val_loss: 1.7338 - val_accuracy: 0.5313
# Epoch 25/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7187 - accuracy: 0.5241 - val_loss: 1.7285 - val_accuracy: 0.5196
# Epoch 26/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7156 - accuracy: 0.5271 - val_loss: 1.7232 - val_accuracy: 0.5204
# Epoch 27/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7142 - accuracy: 0.5255 - val_loss: 1.7243 - val_accuracy: 0.5249
# Epoch 28/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7084 - accuracy: 0.5294 - val_loss: 1.7157 - val_accuracy: 0.5244
# Epoch 29/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.7039 - accuracy: 0.5315 - val_loss: 1.7116 - val_accuracy: 0.5343
# Epoch 30/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.7013 - accuracy: 0.5326 - val_loss: 1.7121 - val_accuracy: 0.5384
# Epoch 31/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.6979 - accuracy: 0.5339 - val_loss: 1.7046 - val_accuracy: 0.5409
# Epoch 32/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.6965 - accuracy: 0.5334 - val_loss: 1.7009 - val_accuracy: 0.5400
# Epoch 33/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.6874 - accuracy: 0.5379 - val_loss: 1.6981 - val_accuracy: 0.5360
# Epoch 34/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.6854 - accuracy: 0.5393 - val_loss: 1.7275 - val_accuracy: 0.5027
# Epoch 35/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.6856 - accuracy: 0.5379 - val_loss: 1.6918 - val_accuracy: 0.5443

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
#    .
#    .
#    .

# Compilamos el modelo
model_with_dp.compile(loss='',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
